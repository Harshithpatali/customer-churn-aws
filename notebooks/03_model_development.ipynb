# %% [markdown]
# # Model Development
# Benchmark models, tune XGBoost with stratified CV and optimize a business threshold.

# %%
from pathlib import Path
from src.pipeline import train
ROOT=Path.cwd()
report=train(ROOT/'data/raw/Telco-Customer-Churn.csv',ROOT/'models')
report

# %%
import json
print(json.dumps(report,indent=2))
