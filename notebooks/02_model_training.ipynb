# %% [markdown]
# # 02 — Feature Engineering & Modeling
# Compare Logistic Regression, Random Forest and XGBoost with stratified evaluation and PR-AUC.

# %%
from pathlib import Path
from src.pipeline import train
report=train(Path('../data/raw/Telco-Customer-Churn.csv'), Path('../models'))
report
