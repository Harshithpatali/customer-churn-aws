# %% [markdown]
# # 03 — Explainability & Retention
# Use SHAP for local explanations and translate risk into retention actions.

# %%
from src.model_service import predict_one, explain_one
# Fill a production customer payload and call these functions.
