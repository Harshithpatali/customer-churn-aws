# %% [markdown]
# # Statistical Modeling
# Association tests and logistic-regression inference are separate from predictive ML evaluation.

# %%
from pathlib import Path
from src.statistics import run_statistics
ROOT=Path.cwd()
summary=run_statistics(ROOT/'data/raw/Telco-Customer-Churn.csv',ROOT/'reports')
summary

# %%
import pandas as pd
pd.read_csv('reports/categorical_significance.csv').head(10)

# %%
pd.read_csv('reports/statistical_logit_odds_ratios.csv')
