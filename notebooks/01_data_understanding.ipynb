# %% [markdown]
# # 01 — IBM Telco Churn: Data Understanding
# Validate schema, missing values, duplicates, target balance and business variables.

# %%
import pandas as pd
df=pd.read_csv('../data/raw/Telco-Customer-Churn.csv')
df.shape, df.head(), df.isna().sum().sort_values(ascending=False).head(10)

# %%
df['TotalCharges']=pd.to_numeric(df['TotalCharges'], errors='coerce')
df['Churn'].value_counts(normalize=True)
