# %% [markdown]
# # SHAP & Retention Intelligence
# Generate global SHAP importance using the same trained artifact used by the API.

# %%
# Reproduce the global analysis:
# python scripts/explainability.py

# %%
import pandas as pd
pd.read_csv('reports/shap_global_importance.csv').head(20)
