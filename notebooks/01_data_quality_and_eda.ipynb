# %% [markdown]
# # Data Quality & EDA
# Validate schema, missingness, duplicates and churn distribution.

# %%
from pathlib import Path
import pandas as pd
from src.data_quality import profile, validate_schema
ROOT=Path.cwd()
df=pd.read_csv(ROOT/'data/raw/Telco-Customer-Churn.csv')
validate_schema(df)
profile(df)

# %%
df.describe(include='all').T

# %%
df['Churn'].value_counts(normalize=True)
